# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.cluster import KMeans 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances

import nltk
nltk.download('stopwords')
nltk.download('punkt')
import string

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')


# email module has some useful functions
import os, sys, email,re
# Out:
# [nltk_data] Downloading package stopwords to /home/ki/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ki/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df = pd.read_csv('projectfinder.csv')
df.dropna(axis=0, inplace=True)
df.head()
df.describe()
# Out:
#                                             skill_summary  \
# count                                                5360
# unique                                               5083
# top     dokumentation, 2nd level support, windows, sup...
# freq                                                   17
#
#                       title                                        description
# count                  5360                                               5360
# unique                 4979                                               5282
# top     Technischer Support  Projektbeschreibung \n\n                      ...
# freq                     23                                                 19

# %%
title = df['title']
description = df['description'].tolist()
skill = df['skill_summary']
print(type(description))
# Out:
# <class 'list'>

# %%
# load nltk's German stopwords'
with open('stopwords-de.txt', 'r') as f:
    stopwords = f.read().splitlines()
print(len(stopwords))
stopwords_eng = nltk.corpus.stopwords.words('english')
stopwords.extend(stopwords_eng)
print(len(stopwords))
# Out:
# 622
# 801

# %%
# load nltk's SnowballStemmer
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("german")

# %%
#here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    #convert text list from list to a string
    text_to_string = ','.join(str(v) for v in text)
    
    # sentence tokenization and lowercasing first, then by word to ensure that punctuation is caught as it's own token
    list_of_tokens = [word.lower() for sentence in nltk.sent_tokenize(text_to_string) for word in nltk.word_tokenize(sentence)]
    
    #extract only alphanumic tokens and add to cleaned_tokens
    alphanumeric_tokens = [token for token in list_of_tokens if token.isalnum()]
    print(alphanumeric_tokens[:20])
    
    #stopwords removal
    cleaned = [word for word in alphanumeric_tokens if word not in stopwords]
    print(cleaned[:20])
    
    #stemming
    stemmed_tokens = [stemmer.stem(token) for token in cleaned]
    print(stemmed_tokens[:20])

    return stemmed_tokens

# this is used only for presentational purposes
def tokenize_only(text):
    #convert text list from list to a string
    text_to_string = ','.join(str(v) for v in text)
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    list_of_tokens = [word.lower() for sent in nltk.sent_tokenize(text_to_string) for word in nltk.word_tokenize(sent)]
    
    #stopwords removal
    cleaned = [word for word in list_of_tokens if word not in stopwords]
    
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    filtered_tokens = [token for token in cleaned if token.isalnum()]
    

    return filtered_tokens

# %%
stemmed_text = tokenize_and_stem(description)
tokenized_text = tokenize_only(description)
#for word in description:
 #   stemmed_word = tokenize_and_stem(word) #for each item in 'synopses', tokenize/stem
  #  all_tokenized = tokenize_only(word)
   # stemmed_text.extend(stemmed_word) #extend the 'totalvocab_stemmed' list
    #tokenized_text.extend(all_tokenized)
# Out:
# ['business', 'intelligence', 'analyst', 'tableau', 'desktop', 'für', 'ein', 'kundenprojekt', 'suchen', 'wir', 'sie', 'als', 'business', 'intelligence', 'analyst', 'tableau', 'desktop', 'der', 'kunde', 'hat']
# ['business', 'intelligence', 'analyst', 'tableau', 'desktop', 'kundenprojekt', 'suchen', 'business', 'intelligence', 'analyst', 'tableau', 'desktop', 'kunde', 'hohes', 'kontinui', 'konzeption', 'customizing', 'softwareanpassungen', 'talend', 'esb']
# ['business', 'intelligenc', 'analyst', 'tableau', 'desktop', 'kundenprojekt', 'such', 'business', 'intelligenc', 'analyst', 'tableau', 'desktop', 'kund', 'hoh', 'kontinui', 'konzeption', 'customizing', 'softwareanpass', 'talend', 'esb']

# %%
vocab_frame = pd.DataFrame({'words': tokenized_text}, index = stemmed_text)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 562931 items in vocab_frame

# %%
vocab_frame.head()
# Out:
#                     words
# business         business
# intelligenc  intelligence
# analyst           analyst
# tableau           tableau
# desktop           desktop

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords)

X = vectorizer.fit_transform(description)
X
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['wahr'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# <5360x31978 sparse matrix of type '<class 'numpy.float64'>'
# 	with 490000 stored elements in Compressed Sparse Row format>

# %%
true_k = 5
model = KMeans(n_clusters=true_k)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

# %%
for i in range(true_k):
    print(f'Cluster {i}')
    print()
    for ind in order_centroids[i, :10]:
        print(terms[ind])
# Out:
# Cluster 0
#
# sap
# bewerben
# abap
# direkt
# melden
# berater
# fi
# erfahrung
# kenntnisse
# hana
# Cluster 1
#
# contractor
# https
# impressum
# www
# de
# münchen
# informationen
# frankfurt
# main
# betroffenenrechte
# Cluster 2
#
# hays
# kontakt
# passende
# bewerben
# positionen
# profitieren
# kostenfrei
# erfahrung
# vorteile
# aufgaben
# Cluster 3
#
# experience
# bewerben
# knowledge
# project
# development
# data
# skills
# sap
# looking
# working
# Cluster 4
#
# bewerben
# direkt
# melden
# kenntnisse
# erfahrung
# java
# entwicklung
# kunden
# projekt
# entwickler

# %%
print("Prediction")
X = vectorizer.transform(["Produktumfeld der Firma VMWARE: Airwatch (sehr gute Kenntnisse)Netzwerktechnik: LAN, DMZ, Rechenzentrum (Vertiefte Kenntnisse) MS-Office Tools: Word, Excel, Visio, Powerpoint (Vertiefte Kenntnisse) Bereitschaft zur Sicherheitsüberprüfung Level 2 (Ü2)"])
predicted = model.predict(X)
print(predicted)
# Out:
# Prediction
# [1]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
 
#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words=stopwords,
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(description) #fit the vectorizer to description

print(tfidf_matrix.shape)
# Out:
# ['w', 'e', 'l', 'c', 'h', 'e', 'm']
# []
# []
# ['d', 'e', 'r', 'e', 'n']
# []
# []
# ['d', 'e', 'n', 'e', 'n']
# []
# []
# ['d', 'i', 'e']
# []
# []
# ['b', 'y']
# []
# []
# ['n', 'o', 'r']
# []
# []
# ['k', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['d', 'e', 's', 's', 'e', 'l', 'b', 'e', 'n']
# []
# []
# ['t', 'h', 'e', 'y']
# []
# []
# ['d', 'u', 'r', 'f', 't', 'e', 'n']
# []
# []
# ['n', 'e', 'u', 'n', 't', 'e']
# []
# []
# ['m', 'u', 's', 't', 'n']
# []
# []
# ['j', 'e', 'n', 'e', 's']
# []
# []
# ['h', 'a', 't', 't', 'e', 'n']
# []
# []
# ['e', 'i', 'n', 'e', 'm']
# []
# []
# ['s', 'e', 'i', 'n', 'e', 'm']
# []
# []
# ['h', 'e', 'i', 's', 's', 't']
# []
# []
# ['v', 'e']
# []
# []
# ['j', 'e', 'm', 'a', 'n', 'd']
# []
# []
# ['e', 'h', 'r', 'l', 'i', 'c', 'h']
# []
# []
# ['m', 'a', 'g', 's', 't']
# []
# []
# ['d', 'a', 'n', 'e', 'b', 'e', 'n']
# []
# []
# ['s', 'a', 'g', 't']
# []
# []
# ['s', 'o', 'l', 'l']
# []
# []
# ['s', 'o', 'l', 'c', 'h', 'e', 'r']
# []
# []
# ['w', 'o', 'r', 'd', 'e', 'n']
# []
# []
# ['d', 'e', 'm', 'g', 'e', 'm', 'ä', 'ß']
# ['ä', 'ß']
# ['a', 'ss']
# ['d', 'a', 'n', 'k']
# []
# []
# ['h', 'i', 'm', 's', 'e', 'l', 'f']
# []
# []
# ['e', 'b', 'e', 'n']
# []
# []
# ['u', 'p']
# []
# []
# ['t', 'u', 'n']
# []
# []
# ['h', 'a', 't', 't', 'e', 's', 't']
# []
# []
# ['w', 'e']
# []
# []
# ['s', 'c', 'h', 'l', 'u', 's', 's']
# []
# []
# ['n', 'i', 'c', 'h', 't', 's']
# []
# []
# ['e', 'r', 's', 't', 'e', 's']
# []
# []
# ['n', 'u', 'n']
# []
# []
# ['f', 'u', 'r', 't', 'h', 'e', 'r']
# []
# []
# ['k', 'l', 'e', 'i', 'n', 'e', 'r']
# []
# []
# ['t', 'h', 'e', 'n']
# []
# []
# ['z', 'w', 'ö', 'l', 'f']
# ['ö']
# ['o']
# ['m', 'a', 'n', 'c', 'h', 'e', 'r']
# []
# []
# ['m', 'u', 'ß', 't']
# ['ß']
# ['ss']
# ['s', 'e', 'i', 'n', 'e', 'r']
# []
# []
# ['a', 's']
# []
# []
# ['w', 'a', 'r', 'u', 'm']
# []
# []
# ['d', 'e', 'r']
# []
# []
# ['v', 'i', 'e', 'l', 'e', 'n']
# []
# []
# ['j', 'e', 'm', 'a', 'n', 'd', 'e', 'n']
# []
# []
# ['e', 'i', 'g', 'e', 'n', 'e']
# []
# []
# ['k', 'e', 'i', 'n']
# []
# []
# ['i', 'r', 'g', 'e', 'n', 'd']
# []
# []
# ['d', 'a', 'm', 'i', 't']
# []
# []
# ['s', 'e', 'c', 'h', 's']
# []
# []
# ['w', 'e', 'r', 'e', 'n', 't']
# []
# []
# ['m', 'ö', 'g', 'e', 'n']
# ['ö']
# ['o']
# ['a', 'l', 'l', 'e']
# []
# []
# ['b', 'i', 's']
# []
# []
# ['m', 'e', 'n', 's', 'c', 'h']
# []
# []
# ['n', 'e', 'u', 'n', 't', 'e', 's']
# []
# []
# ['i', 's', 'n']
# []
# []
# ['s', 'o', 'l', 'c', 'h', 'e', 'm']
# []
# []
# ['b']
# []
# []
# ['d', 'i', 'd', 'n']
# []
# []
# ['m', 'a', 'c', 'h', 't', 'e']
# []
# []
# ['s', 'i', 'e', 'b', 'e', 'n', 't', 'e']
# []
# []
# ['o', 'f']
# []
# []
# ['t', 'h', 'i', 's']
# []
# []
# ['s', 'o', 'm', 'e']
# []
# []
# ['d', 'e', 'r', 's', 'e', 'l', 'b', 'e']
# []
# []
# ['j', 'e', 'n', 'e', 'm']
# []
# []
# ['a', 'b', 'o', 'v', 'e']
# []
# []
# ['t', 'h', 'e', 'i', 'r']
# []
# []
# ['w', 'a', 'r', 'e', 'n']
# []
# []
# ['f', 'u', 'r']
# []
# []
# ['d', 'a', 's', 's', 'e', 'l', 'b', 'e']
# []
# []
# ['s', 'o', 'l', 'l', 't']
# []
# []
# ['l', 'o', 's']
# []
# []
# ['d', 'u', 'r', 'c', 'h']
# []
# []
# ['w', 'a', 'n', 'n']
# []
# []
# ['s', 't', 'a', 'r', 't', 's', 'e', 'i', 't', 'e']
# []
# []
# ['u', 'n', 'd', 'e', 'r']
# []
# []
# ['n', 'i', 'e', 'm', 'a', 'n', 'd', 'e', 'm']
# []
# []
# ['g', 'e', 'm', 'a', 'c', 'h', 't']
# []
# []
# ['n', 'e', 'u', 'n', 't', 'e', 'r']
# []
# []
# ['c', 'o', 'u', 'l', 'd', 'n']
# []
# []
# ['m', 'a', 'n']
# []
# []
# ['h', 'a', 'v', 'i', 'n', 'g']
# []
# []
# ['g', 'r', 'o', 's', 's', 'e', 'r']
# []
# []
# ['s', 'e', 'c', 'h', 's', 't', 'e', 'n']
# []
# []
# ['v', 'e', 'r', 'y']
# []
# []
# ['h', 'e', 'r', 's']
# []
# []
# ['e', 'i', 'n', 'e', 'r']
# []
# []
# ['m', 'u', 's', 's', 't', 'e', 'n']
# []
# []
# ['w', 'o']
# []
# []
# ['s', 'i', 'e', 'b', 'e', 'n']
# []
# []
# ['m', 'i', 'g', 'h', 't', 'n']
# []
# []
# ['w', 'i', 'e', 's', 'o']
# []
# []
# ['d', 'e', 'r', 's', 'e', 'l', 'b', 'e', 'n']
# []
# []
# ['b', 'e', 'i', 's', 'p', 'i', 'e', 'l']
# []
# []
# ['d', 'a', 'h', 'i', 'n', 't', 'e', 'r']
# []
# []
# ['w', 'i', 'l', 'l', 's', 't']
# []
# []
# ['h', 'a', 'b']
# []
# []
# ['w', 'e', 'n', 'i', 'g']
# []
# []
# ['s', 'h', 'o', 'u', 'l', 'd', 'n', 't']
# []
# []
# ['w', 'ä', 'h', 'r', 'e', 'n', 'd', 'd', 'e', 's', 's', 'e', 'n']
# ['ä']
# ['a']
# ['z', 'w', 'e', 'i']
# []
# []
# ['i']
# []
# []
# ['o', 'b']
# []
# []
# ['a', 'n']
# []
# []
# ['u', 'n', 's', 'e']
# []
# []
# ['m', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['m', 'e', 'i', 'n', 'e', 'r']
# []
# []
# ['w', 'h', 'y']
# []
# []
# ['a', 'r', 'e', 'n']
# []
# []
# ['i', 'h', 'm']
# []
# []
# ['i', 't', 's']
# []
# []
# ['j', 'e', 'n', 'e']
# []
# []
# ['a', 'b', 'e', 'r']
# []
# []
# ['d', 'e', 'i', 'n', 'e']
# []
# []
# ['u', 'n', 't', 'i', 'l']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'n']
# []
# []
# ['o', 'd', 'e', 'r']
# []
# []
# ['s', 'o', 'l', 'l', 'e', 'n']
# []
# []
# ['w', 'e', 'n', 'i', 'g', 'e']
# []
# []
# ['l', 'l']
# []
# []
# ['m', 'ü', 's', 's', 't']
# ['ü']
# ['u']
# ['v', 'i', 'e', 'l']
# []
# []
# ['s', 'p', 'ä', 't', 'e', 'r']
# ['ä']
# ['a']
# ['d', 'a', 'm', 'a', 'l', 's']
# []
# []
# ['t', 'a', 't']
# []
# []
# ['e', 'r', 'n', 's', 't']
# []
# []
# ['f', 'o', 'r']
# []
# []
# ['m', 'a', 'n', 'c', 'h', 'e', 's']
# []
# []
# ['c', 'o', 'u', 'l', 'd', 'n', 't']
# []
# []
# ['n', 'i', 'e', 'm', 'a', 'n', 'd']
# []
# []
# ['i', 't', 's']
# []
# []
# ['d', 'u']
# []
# []
# ['s', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['d', 'e', 'n', 'n']
# []
# []
# ['s', 'a', 'g', 't', 'e']
# []
# []
# ['v', 'i', 'e', 'r']
# []
# []
# ['d', 'a', 'f', 'ü', 'r']
# ['ü']
# ['u']
# ['w', 'ü', 'r', 'd', 'e', 'n']
# ['ü']
# ['u']
# ['a', 'u', 'ß', 'e', 'r', 'd', 'e', 'm']
# ['ß']
# ['ss']
# ['m', 'a', 'n', 'n']
# []
# []
# ['e', 'i', 'n', 'i', 'g', 'e']
# []
# []
# ['x']
# []
# []
# ['j']
# []
# []
# ['g', 'e', 's', 'c', 'h', 'w', 'e', 'i', 'g', 'e']
# []
# []
# ['a', 'l', 'l']
# []
# []
# ['c', 'a', 'n']
# []
# []
# ['m', 'ü', 'ß', 't']
# ['ü', 'ß']
# ['u', 'ss']
# ['h', 'a', 's', 'n', 't']
# []
# []
# ['e', 'u', 'r', 'e', 'm']
# []
# []
# ['o', 'b', 'e', 'n']
# []
# []
# ['a', 'l', 'l', 'e', 'r']
# []
# []
# ['z', 'w', 'e', 'i', 't', 'e']
# []
# []
# ['i', 'm', 'm', 'e', 'r']
# []
# []
# ['v', 'i', 'e', 'l', 'l', 'e', 'i', 'c', 'h', 't']
# []
# []
# ['g', 'r', 'o', 'ß', 'e']
# ['ß']
# ['ss']
# ['a', 'n', 'd']
# []
# []
# ['m', 'u', 's', 's', 't']
# []
# []
# ['n', 'e', 'e', 'd', 'n', 't']
# []
# []
# ['k', 'ö', 'n', 'n', 'e', 'n']
# ['ö']
# ['o']
# ['n', 'i', 'e', 'm', 'a', 'n', 'd', 'e', 'n']
# []
# []
# ['g', 'e', 'r', 'a', 'd', 'e']
# []
# []
# ['k', 'ö', 'n', 'n', 't', 'e']
# ['ö']
# ['o']
# ['a', 'n', 'd', 'e', 'r', 's']
# []
# []
# ['e', 'i', 'g', 'e', 'n', 'e', 's']
# []
# []
# ['h', 'e', 'r', 'e']
# []
# []
# ['s', 'e', 'i', 't']
# []
# []
# ['ü', 'b', 'e', 'r', 'h', 'a', 'u', 'p', 't']
# ['ü']
# ['u']
# ['g', 'e', 'w', 'o', 'l', 'l', 't']
# []
# []
# ['e', 'i', 'n', 'a', 'n', 'd', 'e', 'r']
# []
# []
# ['j', 'e', 'd', 'e', 'n']
# []
# []
# ['w', 'e', 'n', 'i', 'g', 'e', 's']
# []
# []
# ['e', 'i', 'n', 'i', 'g']
# []
# []
# ['w', 'i', 'r', 'k', 'l', 'i', 'c', 'h']
# []
# []
# ['a', 'i', 'n']
# []
# []
# ['v', 'i', 'e', 'r', 't', 'e']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'r']
# []
# []
# ['g', 'e', 'h', 't']
# []
# []
# ['o', 'u', 'r']
# []
# []
# ['o', 'v', 'e', 'r']
# []
# []
# ['h', 'i', 'e', 'r']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'e']
# []
# []
# ['s', 'e', 'c', 'h', 's', 't', 'e', 'r']
# []
# []
# ['v', 'o', 'r']
# []
# []
# ['w', 'e', 'r', 'e']
# []
# []
# ['g', 'a', 'r']
# []
# []
# ['n', 'e', 'u', 'e']
# []
# []
# ['w', 'e', 'i', 't', 'e', 'r']
# []
# []
# ['w', 'h', 'a', 't']
# []
# []
# ['e', 'b', 'e', 'n', 's', 'o']
# []
# []
# ['b', 'e', 'i', 'm']
# []
# []
# ['w', 'e', 'i', 't', 'e', 'r', 'e', 'n']
# []
# []
# ['z', 'e', 'h', 'n', 't', 'e', 'n']
# []
# []
# ['t', 'a', 'g']
# []
# []
# ['d', 'e', 's', 'h', 'a', 'l', 'b']
# []
# []
# ['n', 'e', 'i', 'n']
# []
# []
# ['b', 'e', 'c', 'a', 'u', 's', 'e']
# []
# []
# ['d', 'e', 'm', 's', 'e', 'l', 'b', 'e', 'n']
# []
# []
# ['s', 'u', 'c', 'h']
# []
# []
# ['a']
# []
# []
# ['g', 'a', 'n', 'z', 'e', 's']
# []
# []
# ['d', 'a', 'g', 'e', 'g', 'e', 'n']
# []
# []
# ['j', 'e', 'd', 'e', 's']
# []
# []
# ['m', 'e', 'i', 'n', 'e', 'm']
# []
# []
# ['k', 'e', 'i', 'n', 'e']
# []
# []
# ['p']
# []
# []
# ['w', 'e', 'm']
# []
# []
# ['m', 'e', 'i', 'n']
# []
# []
# ['s', 'e', 'l', 'b', 's', 't']
# []
# []
# ['f', 'ü', 'n', 'f', 't', 'e', 's']
# ['ü']
# ['u']
# ['e', 'i', 'n', 'i', 'g', 'e', 'r']
# []
# []
# ['w', 'i', 'l', 'l']
# []
# []
# ['m', 'ö', 'c', 'h', 't', 'e']
# ['ö']
# ['o']
# ['a', 'u', 's']
# []
# []
# ['f', 'ü', 'n', 'f', 't', 'e', 'r']
# ['ü']
# ['u']
# ['w', 'u', 'r', 'd', 'e']
# []
# []
# ['y', 'o', 'u', 'r', 's', 'e', 'l', 'v', 'e', 's']
# []
# []
# ['e', 'n']
# []
# []
# ['e', 'i', 'n', 'e', 'n']
# []
# []
# ['o', 'u', 't']
# []
# []
# ['s', 'o', 'l', 'l', 't', 'e', 'n']
# []
# []
# ['g', 'a', 'n', 'z', 'e']
# []
# []
# ['w', 'i', 'e']
# []
# []
# ['i', 'n', 't', 'o']
# []
# []
# ['s', 'e', 'i', 'n', 'e']
# []
# []
# ['e', 'i', 'g', 'e', 'n', 'e', 'r']
# []
# []
# ['b', 'e', 'i', 'd', 'e', 'n']
# []
# []
# ['w', 'a', 's']
# []
# []
# ['t', 'o']
# []
# []
# ['k', 'e', 'i', 'n', 'e', 's']
# []
# []
# ['s', 'o', 'n', 's', 't']
# []
# []
# ['d', 'e', 's']
# []
# []
# ['z', 'e', 'h', 'n', 't', 'e', 's']
# []
# []
# ['a', 'c', 'h', 't', 'e', 'n']
# []
# []
# ['w', 'a', 's', 'n']
# []
# []
# ['m', 'e', 'i', 'n', 'e']
# []
# []
# ['m', 'e', 'n', 's', 'c', 'h', 'e', 'n']
# []
# []
# ['m', 'u', 's', 's', 't', 'e']
# []
# []
# ['w', 'h', 'i', 'l', 'e']
# []
# []
# ['d', 'i', 'e', 's', 'e', 'm']
# []
# []
# ['g', 'r', 'o', 'ß', 'e', 's']
# ['ß']
# ['ss']
# ['y', 'o', 'u', 'r', 's']
# []
# []
# ['s', 'e', 'i', 't', 'd', 'e', 'm']
# []
# []
# ['v', 'i', 'e', 'l', 'e', 'm']
# []
# []
# ['a', 'g', 'a', 'i', 'n']
# []
# []
# ['g', 'o', 't', 't']
# []
# []
# ['i', 'h', 'r', 'e', 'r']
# []
# []
# ['w', 'e', 'n', 'n']
# []
# []
# ['n', 'e', 'b', 'e', 'n']
# []
# []
# ['y', 'o', 'u', 'd']
# []
# []
# ['a', 'm']
# []
# []
# ['s', 'e', 'i', 'd']
# []
# []
# ['s', 'e', 'i', 'n']
# []
# []
# ['s', 'o', 'l', 'l', 't', 'e']
# []
# []
# ['d', 'i', 'e', 's', 'e', 'l', 'b', 'e', 'n']
# []
# []
# ['d', 'i', 'e', 'j', 'e', 'n', 'i', 'g', 'e']
# []
# []
# ['k', 'o', 'm', 'm', 'e', 'n']
# []
# []
# ['g', 'i', 'n', 'g']
# []
# []
# ['k', 'u', 'r', 'z']
# []
# []
# ['h']
# []
# []
# ['d', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['s', 'o', 'l', 'a', 'n', 'g']
# []
# []
# ['z', 'u', 'g', 'l', 'e', 'i', 'c', 'h']
# []
# []
# ['w', 'a', 'r', 's', 't']
# []
# []
# ['m', 'a', 'c', 'h', 'e', 'n']
# []
# []
# ['d', 'a', 'n', 'a', 'c', 'h']
# []
# []
# ['n', 'a', 'c', 'h']
# []
# []
# ['d', 'ü', 'r', 'f', 't']
# ['ü']
# ['u']
# ['k', 'l', 'e', 'i', 'n', 'e']
# []
# []
# ['h', 'i', 'm']
# []
# []
# ['i', 't']
# []
# []
# ['w', 'o', 'u', 'l', 'd', 'n', 't']
# []
# []
# ['h', 'e', 'r']
# []
# []
# ['h', 'o', 'c', 'h']
# []
# []
# ['g', 'e', 'n', 'u', 'g']
# []
# []
# ['i', 'h', 'r', 'e', 'n']
# []
# []
# ['h', 'a', 's']
# []
# []
# ['g', 'e', 'w', 'e', 's', 'e', 'n']
# []
# []
# ['k']
# []
# []
# ['e', 'n', 'd', 'e']
# []
# []
# ['w', 'ä', 'r', 'e']
# ['ä']
# ['a']
# ['e']
# []
# []
# ['z']
# []
# []
# ['n', 'a', 'c', 'h', 'd', 'e', 'm']
# []
# []
# ['h', 'ä', 't', 't', 'e', 'n']
# ['ä']
# ['a']
# ['s', 'i', 'e']
# []
# []
# ['a', 'u', 'ß', 'e', 'r']
# ['ß']
# ['ss']
# ['w', 'e', 'n', 'i', 'g', 's', 't', 'e', 'n', 's']
# []
# []
# ['d']
# []
# []
# ['f', 'ü', 'r']
# ['ü']
# ['u']
# ['j', 'a', 'h', 'r', 'e', 'n']
# []
# []
# ['w', 'o', 'n', 't']
# []
# []
# ['k', 'e', 'i', 'n', 'e', 'm']
# []
# []
# ['t', 'h', 'e', 's', 'e']
# []
# []
# ['g', 'e', 'm', 'o', 'c', 'h', 't']
# []
# []
# ['s', 'o', 'l', 'c', 'h', 'e', 'n']
# []
# []
# ['w', 'h', 'o']
# []
# []
# ['a', 'r', 'e', 'n', 't']
# []
# []
# ['d', 'a', 'n', 'n']
# []
# []
# ['k', 'a', 'm']
# []
# []
# ['w', 'h', 'o', 'm']
# []
# []
# ['o', 'h', 'n', 'e']
# []
# []
# ['a', 'c', 'h']
# []
# []
# ['m', 'u', 'ß']
# ['ß']
# ['ss']
# ['n', 'o', 'w']
# []
# []
# ['l', 'a', 'n', 'g', 'e']
# []
# []
# ['d', 'e', 'i', 'n', 'e', 'm']
# []
# []
# ['a', 'l', 'l', 'e', 'm']
# []
# []
# ['l', 'e', 'i', 'd', 'e']
# []
# []
# ['h', 'i', 'n', 't', 'e', 'r']
# []
# []
# ['m', 'o', 's', 't']
# []
# []
# ['a', 'l', 'l', 'e', 'i', 'n']
# []
# []
# ['m', 'i', 't', 't', 'e', 'l']
# []
# []
# ['n', 'u', 'r']
# []
# []
# ['r', 'e', 'c', 'h', 't', 'e', 's']
# []
# []
# ['t', 'h', 'e']
# []
# []
# ['r', 'e', 'c', 'h', 't', 'e', 'r']
# []
# []
# ['s', 'h', 'a', 'n']
# []
# []
# ['a', 'n', 'd', 'e', 'r']
# []
# []
# ['d', 'o', 'e', 's', 'n', 't']
# []
# []
# ['b', 'a', 'l', 'd']
# []
# []
# ['s', 'o', 'w', 'i', 'e']
# []
# []
# ['w', 'a', 'h', 'r']
# []
# []
# ['e', 'i', 'n', 'i', 'g', 'e', 's']
# []
# []
# ['z', 'u', 's', 'a', 'm', 'm', 'e', 'n']
# []
# []
# ['a', 'l', 'l', 'g', 'e', 'm', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['d', 'i', 'e', 'j', 'e', 'n', 'i', 'g', 'e', 'n']
# []
# []
# ['t', 'h', 'e', 'm', 's', 'e', 'l', 'v', 'e', 's']
# []
# []
# ['d', 'a', 'b', 'e', 'i']
# []
# []
# ['s', 'o', 'w', 'e', 'i', 't']
# []
# []
# ['a', 'c', 'h', 't']
# []
# []
# ['d', 'a', 'r', 'a', 'u', 'f']
# []
# []
# ['s', 'o', 'n', 'd', 'e', 'r', 'n']
# []
# []
# ['w', 'ä', 'h', 'r', 'e', 'n', 'd']
# ['ä']
# ['a']
# ['d', 'e', 'm', 'g', 'e', 'g', 'e', 'n', 'ü', 'b', 'e', 'r']
# ['ü']
# ['u']
# ['j', 'e', 'n', 'e', 'n']
# []
# []
# ['h', 'a', 't', 't', 'e', 't']
# []
# []
# ['d', 'r', 'i', 't', 't', 'e', 'n']
# []
# []
# ['h', 'a', 'd', 'n', 't']
# []
# []
# ['w', 'e', 'g']
# []
# []
# ['h', 'o', 'w']
# []
# []
# ['z', 'b']
# []
# []
# ['b', 'e', 'i', 'n', 'g']
# []
# []
# ['a', 'g']
# []
# []
# ['s', 'c', 'h', 'o', 'n']
# []
# []
# ['r', 'u', 'n', 'd']
# []
# []
# ['u', 'n', 's', 'e', 's']
# []
# []
# ['a', 'u', 's', 's', 'e', 'r']
# []
# []
# ['f', 'r', 'o', 'm']
# []
# []
# ['n', 'e', 'u', 'n']
# []
# []
# ['e', 'r']
# []
# []
# ['d', 'o', 'i', 'n', 'g']
# []
# []
# ['d', 'a', 'r', 'a', 'n']
# []
# []
# ['w', 'e', 'r', 'd', 'e', 'n']
# []
# []
# ['y', 'o', 'u', 'l', 'l']
# []
# []
# ['y', 'o', 'u']
# []
# []
# ['e', 't', 'w', 'a']
# []
# []
# ['h', 'a', 't']
# []
# []
# ['m', 'a', 'g']
# []
# []
# ['d', 'i', 'r']
# []
# []
# ['c']
# []
# []
# ['d', 'r', 'e', 'i']
# []
# []
# ['l', 'a', 'n', 'g']
# []
# []
# ['w', 'e', 'n', 'i', 'g', 'e', 'r']
# []
# []
# ['o', 'n', 'l', 'y']
# []
# []
# ['a', 'l', 'l', 'e', 's']
# []
# []
# ['w', 'e', 'r', 'd', 'e', 't']
# []
# []
# ['t', 'h', 'a', 't', 'l', 'l']
# []
# []
# ['q']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'e', 'n']
# []
# []
# ['m', 'e']
# []
# []
# ['d', 'i', 'd', 'n', 't']
# []
# []
# ['g', 'u', 't']
# []
# []
# ['g', 'e', 'h', 'a', 'b', 't']
# []
# []
# ['k', 'e', 'i', 'n', 'e', 'r']
# []
# []
# ['w', 'e', 'l', 'c', 'h', 'e', 's']
# []
# []
# ['h', 'e', 'u', 't', 'e']
# []
# []
# ['d', 'e', 'm', 'e', 'n', 't', 's', 'p', 'r', 'e', 'c', 'h', 'e', 'n', 'd']
# []
# []
# ['i', 's', 't']
# []
# []
# ['w', 'a', 'r', 't']
# []
# []
# ['a', 'b', 'o', 'u', 't']
# []
# []
# ['m', 'a', 'n', 'c', 'h', 'e']
# []
# []
# ['r', 'e', 'c', 'h', 't', 'e', 'n']
# []
# []
# ['d', 'a', 'v', 'o', 'r']
# []
# []
# ['d', 'i', 'e', 's', 'e', 'l', 'b', 'e']
# []
# []
# ['y', 'o', 'u', 'r', 'e']
# []
# []
# ['s', 'e', 'i']
# []
# []
# ['v', 'i', 'e', 'l', 'e']
# []
# []
# ['w', 'e', 's', 'h', 'a', 'l', 'b']
# []
# []
# ['n']
# []
# []
# ['d', 'a', 'h', 'i', 'n']
# []
# []
# ['b', 'e', 'l', 'o', 'w']
# []
# []
# ['e', 'n', 'd', 'l', 'i', 'c', 'h']
# []
# []
# ['d', 'i', 'e', 's']
# []
# []
# ['i', 'n', 's']
# []
# []
# ['w']
# []
# []
# ['d', 'e', 's', 's', 'e', 'n']
# []
# []
# ['h', 'a', 'b', 'e']
# []
# []
# ['s', 'a', 'h']
# []
# []
# ['s', 'o', 'l', 'l', 's', 't']
# []
# []
# ['w', 'o', 'h', 'i', 'n']
# []
# []
# ['u', 'n', 's', 'e', 'm']
# []
# []
# ['m', 'o', 'r', 'g', 'e', 'n']
# []
# []
# ['z', 'w', 'e', 'i', 't', 'e', 'r']
# []
# []
# ['m', 'ü', 's', 's', 'e', 'n']
# ['ü']
# ['u']
# ['n', 'o', 't']
# []
# []
# ['i', 'h', 'r', 'e', 'm']
# []
# []
# ['s', 'e', 'c', 'h', 's', 't', 'e']
# []
# []
# ['d', 'e', 's', 'w', 'e', 'g', 'e', 'n']
# []
# []
# ['n', 'a', 'h', 'm']
# []
# []
# ['a', 't']
# []
# []
# ['d', 'o', 'w', 'n']
# []
# []
# ['d', 'e', 'm']
# []
# []
# ['l', 'e', 'i', 'c', 'h', 't']
# []
# []
# ['h', 'a', 'b', 't']
# []
# []
# ['d', 'i', 'e', 's', 'e', 'r']
# []
# []
# ['u', 'n', 't', 'e', 'r']
# []
# []
# ['s', 'h', 'e']
# []
# []
# ['b', 'e', 'k', 'a', 'n', 'n', 't']
# []
# []
# ['j', 'e']
# []
# []
# ['b', 'o', 't', 'h']
# []
# []
# ['d', 'e', 'm', 'g', 'e', 'm', 'ä', 's', 's']
# ['ä']
# ['a']
# ['o', 'u', 'r', 's']
# []
# []
# ['m', 'a', 'l']
# []
# []
# ['m', 'o', 'r', 'e']
# []
# []
# ['d', 'a', 'h', 'e', 'r']
# []
# []
# ['e', 'i']
# []
# []
# ['z', 'u', 'm']
# []
# []
# ['e', 's']
# []
# []
# ['m', 'i', 'c', 'h']
# []
# []
# ['u', 'n', 's', 'e', 'r', 'e']
# []
# []
# ['z', 'u']
# []
# []
# ['w', 'o', 'u', 'l', 'd', 'n']
# []
# []
# ['m', 'a', 'n', 'c', 'h', 'e', 'n']
# []
# []
# ['e', 'r', 's', 't']
# []
# []
# ['g', 'r', 'o', 's', 's']
# []
# []
# ['e', 'i', 'g', 'e', 'n', 'e', 'n']
# []
# []
# ['h', 'a', 's', 't']
# []
# []
# ['s', 'e', 'i', 'n', 'e', 's']
# []
# []
# ['w', 'e', 'n']
# []
# []
# ['e', 'u', 'r', 'e', 'n']
# []
# []
# ['d', 'a', 'r', 'ü', 'b', 'e', 'r']
# ['ü']
# ['u']
# ['d', 'e', 'r', 'j', 'e', 'n', 'i', 'g', 'e']
# []
# []
# ['b', 'u', 't']
# []
# []
# ['v', 'o', 'm']
# []
# []
# ['d', 'r', 'i', 't', 't', 'e']
# []
# []
# ['e', 'i', 'n', 'i', 'g', 'e', 'm']
# []
# []
# ['d', 'e', 'm', 'z', 'u', 'f', 'o', 'l', 'g', 'e']
# []
# []
# ['g', 'e', 'd', 'u', 'r', 'f', 't']
# []
# []
# ['w', 'a', 's', 'n', 't']
# []
# []
# ['u', 'n', 's']
# []
# []
# ['b', 'i', 'n']
# []
# []
# ['s', 'a', 't', 't']
# []
# []
# ['s', 't', 'a', 't', 't']
# []
# []
# ['w', 'e', 'l', 'c', 'h', 'e']
# []
# []
# ['e', 't', 'w', 'a', 's']
# []
# []
# ['f', 'o', 'l', 'g', 'e', 'n', 'd', 'e']
# []
# []
# ['w', 'h', 'i', 'c', 'h']
# []
# []
# ['h', 'a', 't', 't', 'e']
# []
# []
# ['d', 'h']
# []
# []
# ['f', 'ü', 'n', 'f', 't', 'e']
# ['ü']
# ['u']
# ['m', 'a', 'n', 'c', 'h', 'e', 'm']
# []
# []
# ['n', 'a']
# []
# []
# ['e', 'u', 'r', 'e', 's']
# []
# []
# ['i', 'h', 'r', 'e']
# []
# []
# ['u', 'n', 'd']
# []
# []
# ['d', 'a', 'z', 'w', 'i', 's', 'c', 'h', 'e', 'n']
# []
# []
# ['s', 'a', 'm', 'e']
# []
# []
# ['t', 'e', 'i', 'l']
# []
# []
# ['d', 'a', 'd', 'u', 'r', 'c', 'h']
# []
# []
# ['m', 'i', 'g', 'h', 't', 'n', 't']
# []
# []
# ['e', 'i', 'n', 'e', 's']
# []
# []
# ['a', 'l', 's', 'o']
# []
# []
# ['h', 'e']
# []
# []
# ['t']
# []
# []
# ['w', 'e', 'i', 't', 'e', 'r', 'e', 's']
# []
# []
# ['i', 't', 's', 'e', 'l', 'f']
# []
# []
# ['e', 'r', 's', 't', 'e', 'r']
# []
# []
# ['i', 'm']
# []
# []
# ['e', 'u', 'r', 'e']
# []
# []
# ['u', 'n', 's', 'e', 'n']
# []
# []
# ['g', 'a', 'n', 'z', 'e', 'r']
# []
# []
# ['d', 'o', 'e', 's', 'n']
# []
# []
# ['g', 'u', 't', 'e', 's']
# []
# []
# ['d', 'o', 'n']
# []
# []
# ['s', 'h', 'a', 'n', 't']
# []
# []
# ['m', 'i', 't']
# []
# []
# ['m']
# []
# []
# ['e', 'u', 'c', 'h']
# []
# []
# ['d', 'i', 'e', 's', 'e', 's']
# []
# []
# ['b', 'i', 's', 'h', 'e', 'r']
# []
# []
# ['t', 'r', 'o', 't', 'z', 'd', 'e', 'm']
# []
# []
# ['e', 'i', 'g', 'e', 'n']
# []
# []
# ['r', 'e', 'c', 'h', 't']
# []
# []
# ['o', 'r', 'd', 'n', 'u', 'n', 'g']
# []
# []
# ['s', 'h', 'o', 'u', 'l', 'd', 'v', 'e']
# []
# []
# ['g', 'e', 'k', 'a', 'n', 'n', 't']
# []
# []
# ['f', 'ü', 'n', 'f']
# ['ü']
# ['u']
# ['s', 'o', 'l', 'c', 'h', 'e', 's']
# []
# []
# ['g', 'e', 'g', 'e', 'n', 'ü', 'b', 'e', 'r']
# ['ü']
# ['u']
# ['r', 'e', 'c', 'h', 't', 'e']
# []
# []
# ['d', 'a', 's', 'e', 'l', 'b', 's', 't']
# []
# []
# ['w', 'u', 'r', 'd', 'e', 'n']
# []
# []
# ['k', 'l', 'e', 'i', 'n', 'e', 'n']
# []
# []
# ['h', 'ä', 't', 't', 'e']
# ['ä']
# ['a']
# ['s', 'h', 'o', 'u', 'l', 'd', 'n']
# []
# []
# ['g', 'e', 'm', 'u', 's', 's', 't']
# []
# []
# ['t', 'h', 'e', 'i', 'r', 's']
# []
# []
# ['y', 'o', 'u', 'v', 'e']
# []
# []
# ['g', 'a', 'b']
# []
# []
# ['w', 'i', 's', 's', 'e', 'n']
# []
# []
# ['m', 'e', 'i', 'n', 'e', 's']
# []
# []
# ['f', 'e', 'w']
# []
# []
# ['n', 'o']
# []
# []
# ['o', 'w', 'n']
# []
# []
# ['d', 'e', 'r', 'm', 'a', 'ß', 'e', 'n']
# ['ß']
# ['ss']
# ['a', 'n', 'd', 'e', 'r', 'e', 's']
# []
# []
# ['ü', 'b', 'e', 'r']
# ['ü']
# ['u']
# ['d', 'a', 'ß']
# ['ß']
# ['ss']
# ['v', 'i', 'e', 'r', 't', 'e', 's']
# []
# []
# ['m', 'u', 's', 't', 'n', 't']
# []
# []
# ['t', 'h', 'e', 'r', 'e']
# []
# []
# ['f', 'ü', 'n', 'f', 't', 'e', 'n']
# ['ü']
# ['u']
# ['z', 'u', 'n', 'ä', 'c', 'h', 's', 't']
# ['ä']
# ['a']
# ['g', 'e', 'k', 'o', 'n', 'n', 't']
# []
# []
# ['j', 'e', 'd', 'e', 'r']
# []
# []
# ['d', 'r', 'i', 'n']
# []
# []
# ['d', 'a', 'z', 'u']
# []
# []
# ['w', 'o', 'h', 'l']
# []
# []
# ['o', 'r']
# []
# []
# ['m', 'o', 'c', 'h', 't', 'e', 'n']
# []
# []
# ['a', 'c', 'h', 't', 'e', 's']
# []
# []
# ['s', 'i', 'e', 'b', 'e', 'n', 't', 'e', 's']
# []
# []
# ['j', 'e', 'd', 'e', 'm']
# []
# []
# ['o', 'u', 'r', 's', 'e', 'l', 'v', 'e', 's']
# []
# []
# ['a', 'u', 'c', 'h']
# []
# []
# ['e', 'r', 's', 't', 'e', 'n']
# []
# []
# ['w', 'e', 'i', 'l']
# []
# []
# ['w', 'e', 'r', 'e', 'n']
# []
# []
# ['s']
# []
# []
# ['n', 'e', 'u', 'e', 'n']
# []
# []
# ['i', 'h', 'r']
# []
# []
# ['s', 'i', 'e', 'b', 'e', 'n', 't', 'e', 'r']
# []
# []
# ['b', 'e']
# []
# []
# ['s', 'i', 'e', 'b', 'e', 'n', 't', 'e', 'n']
# []
# []
# ['m', 'o', 'c', 'h', 't', 'e']
# []
# []
# ['e', 'i', 'n']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'e', 'r']
# []
# []
# ['k', 'a', 'n', 'n', 's', 't']
# []
# []
# ['t', 'h', 'e', 'm']
# []
# []
# ['b', 'e', 'e', 'n']
# []
# []
# ['d', 'i', 'c', 'h']
# []
# []
# ['g', 'e', 'g', 'e', 'n']
# []
# []
# ['d', 'i', 'e', 's', 'e']
# []
# []
# ['k', 'o', 'n', 'n', 't', 'e']
# []
# []
# ['ü', 'b', 'r', 'i', 'g', 'e', 'n', 's']
# ['ü']
# ['u']
# ['e', 'r', 's', 't', 'e']
# []
# []
# ['u']
# []
# []
# ['w', 'i', 'r', 's', 't']
# []
# []
# ['d', 'e', 'i', 'n']
# []
# []
# ['d', 'o', 'r', 't']
# []
# []
# ['d', 'r', 'i', 't', 't', 'e', 's']
# []
# []
# ['s', 'o', 'l', 'c', 'h', 'e']
# []
# []
# ['w', 'e', 'l', 'c', 'h', 'e', 'n']
# []
# []
# ['y', 'o', 'u', 'r', 's', 'e', 'l', 'f']
# []
# []
# ['o', 'f', 't']
# []
# []
# ['m', 'e', 'h', 'r']
# []
# []
# ['g', 'i', 'b', 't']
# []
# []
# ['g', 'a', 'n', 'z']
# []
# []
# ['t', 'a', 'g', 'e']
# []
# []
# ['w', 'i', 't', 'h']
# []
# []
# ['g', 'r', 'o', 's', 's', 'e', 'n']
# []
# []
# ['a', 'n', 'y']
# []
# []
# ['t', 'e', 'l']
# []
# []
# ['w', 'e', 'g', 'e', 'n']
# []
# []
# ['h', 'i', 's']
# []
# []
# ['t', 'h', 'a', 'n']
# []
# []
# ['i', 's']
# []
# []
# ['d', 'e', 'r', 'j', 'e', 'n', 'i', 'g', 'e', 'n']
# []
# []
# ['z', 'w', 'e', 'i', 't', 'e', 's']
# []
# []
# ['s', 'e', 'i', 'e', 'n']
# []
# []
# ['w', 'e', 'r']
# []
# []
# ['a', 'c', 'h', 't', 'e']
# []
# []
# ['a', 'r', 'e']
# []
# []
# ['v', 'o', 'n']
# []
# []
# ['o', 'n', 'c', 'e']
# []
# []
# ['b', 'i', 's', 't']
# []
# []
# ['s', 'a']
# []
# []
# ['h', 'a', 'v', 'e']
# []
# []
# ['k', 'a', 'n', 'n']
# []
# []
# ['g', 'r', 'o', 'ß']
# ['ß']
# ['ss']
# ['d', 'o', 'n', 't']
# []
# []
# ['k', 'ö', 'n', 'n', 't']
# ['ö']
# ['o']
# ['i', 'n']
# []
# []
# ['a', 'l', 'l', 'e', 'n']
# []
# []
# ['a', 'g', 'a', 'i', 'n', 's', 't']
# []
# []
# ['f']
# []
# []
# ['n', 'a', 't', 'ü', 'r', 'l', 'i', 'c', 'h']
# ['ü']
# ['u']
# ['r', 'i', 'c', 'h', 't', 'i', 'g']
# []
# []
# ['d', 'i', 'd']
# []
# []
# ['b', 'e', 's', 't', 'e', 'n']
# []
# []
# ['g', 'r', 'o', 'ß', 'e', 'n']
# ['ß']
# ['ss']
# ['n', 'i', 'e']
# []
# []
# ['z', 'w', 'a', 'r']
# []
# []
# ['w', 'a', 'r']
# []
# []
# ['w', 'e', 'l', 'c', 'h', 'e', 'r']
# []
# []
# ['s', 'e', 'c', 'h', 's', 't', 'e', 's']
# []
# []
# ['g', 'e', 'r', 'n']
# []
# []
# ['d', 'a', 'r', 'u', 'm']
# []
# []
# ['g', 'l', 'e', 'i', 'c', 'h']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'e', 'm']
# []
# []
# ['d', 'a', 'r', 'a', 'u', 's']
# []
# []
# ['m', 'y', 's', 'e', 'l', 'f']
# []
# []
# ['d', 'o']
# []
# []
# ['t', 'h', 'o', 's', 'e']
# []
# []
# ['z', 'u', 'e', 'r', 's', 't']
# []
# []
# ['t', 'h', 'r', 'o', 'u', 'g', 'h']
# []
# []
# ['w', 'ä', 'h', 'r', 'e', 'n', 'd', 'd', 'e', 'm']
# ['ä']
# ['a']
# ['e', 'i', 'n', 'm', 'a', 'l']
# []
# []
# ['m', 'u', 's', 's']
# []
# []
# ['z', 'e', 'h', 'n', 't', 'e', 'r']
# []
# []
# ['y']
# []
# []
# ['d', 'u', 'r', 'i', 'n', 'g']
# []
# []
# ['n', 'e', 'e', 'd', 'n']
# []
# []
# ['k', 'o', 'n', 'n', 't', 'e', 'n']
# []
# []
# ['w', 'o', 'n']
# []
# []
# ['j', 'e', 'd', 'o', 'c', 'h']
# []
# []
# ['w', 'e', 'r', 'd', 'e']
# []
# []
# ['n', 'e', 'u', 'n', 't', 'e', 'n']
# []
# []
# ['w', 'ü', 'r', 'd', 'e']
# ['ü']
# ['u']
# ['g', 'r', 'o', 's', 's', 'e']
# []
# []
# ['t', 'r', 'i', 't', 't']
# []
# []
# ['d', 'a', 'r', 'f', 's', 't']
# []
# []
# ['w', 'i', 'r']
# []
# []
# ['w', 'i', 'r', 'd']
# []
# []
# ['t', 'h', 'a', 't']
# []
# []
# ['i', 'c', 'h']
# []
# []
# ['s', 'h', 'o', 'u', 'l', 'd']
# []
# []
# ['w', 'e', 's', 's', 'e', 'n']
# []
# []
# ['o']
# []
# []
# ['d', 'a', 's']
# []
# []
# ['i', 'h', 'r', 'e', 's']
# []
# []
# ['m', 'i', 'r']
# []
# []
# ['s', 'i', 'n', 'd']
# []
# []
# ['d', 'e', 'r', 'm', 'a', 's', 's', 'e', 'n']
# []
# []
# ['m', 'ö', 'g', 't']
# ['ö']
# ['o']
# ['e', 'u', 'r', 'e', 'r']
# []
# []
# ['l', 'i', 'e', 'b', 'e', 'r']
# []
# []
# ['v']
# []
# []
# ['w', 'o', 'l', 'l', 'e', 'n']
# []
# []
# ['h', 'e', 'r', 's', 'e', 'l', 'f']
# []
# []
# ['w', 'o', 'l', 'l', 't', 'e', 'n']
# []
# []
# ['b', 'e', 't', 'w', 'e', 'e', 'n']
# []
# []
# ['h', 'a', 'd', 'n']
# []
# []
# ['s', 'i', 'c', 'h']
# []
# []
# ['h', 'a', 'v', 'e', 'n', 't']
# []
# []
# ['w', 'i', 'e', 'd', 'e', 'r']
# []
# []
# ['a', 'b']
# []
# []
# ['z', 'u', 'r']
# []
# []
# ['e', 'i', 'n', 's']
# []
# []
# ['s', 't', 'e', 'h', 't']
# []
# []
# ['j', 'e', 't', 'z', 't']
# []
# []
# ['z', 'w', 'i', 's', 'c', 'h', 'e', 'n']
# []
# []
# ['a', 'l', 's']
# []
# []
# ['h', 'a', 's', 'n']
# []
# []
# ['s', 'a', 'c', 'h', 'e']
# []
# []
# ['w', 'h', 'e', 'n']
# []
# []
# ['g']
# []
# []
# ['d', 'r', 'i', 't', 't', 'e', 'r']
# []
# []
# ['j', 'e', 'n', 'e', 'r']
# []
# []
# ['d', 'a', 'r', 'i', 'n']
# []
# []
# ['j', 'e', 'd', 'e', 'r', 'm', 'a', 'n', 'n', 's']
# []
# []
# ['r']
# []
# []
# ['w', 'o', 'l', 'l', 't', 'e']
# []
# []
# ['e', 'a', 'c', 'h']
# []
# []
# ['d', 'a', 's', 's']
# []
# []
# ['j', 'e', 'm', 'a', 'n', 'd', 'e', 'm']
# []
# []
# ['s', 'o']
# []
# []
# ['v', 'i', 'e', 'r', 't', 'e', 'r']
# []
# []
# ['e', 'i']
# []
# []
# ['g', 'r', 'o', 's', 's', 'e', 's']
# []
# []
# ['h', 'a', 'd']
# []
# []
# ['g', 'a', 'n', 'z', 'e', 'n']
# []
# []
# ['d', 'i', 'e', 's', 'e', 'n']
# []
# []
# ['d', 'u', 'r', 'c', 'h', 'a', 'u', 's']
# []
# []
# ['g', 'u', 't', 'e', 'r']
# []
# []
# ['k', 'a', 'u', 'm']
# []
# []
# ['v', 'i', 'e', 'r', 't', 'e', 'n']
# []
# []
# ['g', 'u', 't', 'e']
# []
# []
# ['w', 'o', 'l', 'l', 't']
# []
# []
# ['z', 'e', 'h', 'n', 't', 'e']
# []
# []
# ['d', 'ü', 'r', 'f', 'e', 'n']
# ['ü']
# ['u']
# ['i', 'h', 'n', 'e', 'n']
# []
# []
# ['d', 'a', 'v', 'o', 'n']
# []
# []
# ['u', 'h', 'r']
# []
# []
# ['j', 'e', 'd', 'e']
# []
# []
# ['g', 'r', 'o', 'ß', 'e', 'r']
# ['ß']
# ['ss']
# ['h', 'a', 'b', 'e', 'n']
# []
# []
# ['w', 'o', 'h', 'e', 'r']
# []
# []
# ['a', 'n', 'd', 'e', 'r', 'm']
# []
# []
# ['f', 'r', 'ü', 'h', 'e', 'r']
# ['ü']
# ['u']
# ['d', 'a', 's', 'e', 'i', 'n']
# []
# []
# ['s', 'c', 'h', 'l', 'e', 'c', 'h', 't']
# []
# []
# ['u', 'n', 's', 'e', 'r']
# []
# []
# ['d', 'a']
# []
# []
# ['z', 'w', 'a', 'n', 'z', 'i', 'g']
# []
# []
# ['k', 'l', 'e', 'i', 'n', 'e', 's']
# []
# []
# ['u', 'm']
# []
# []
# ['a', 'l', 'l', 'e', 'r', 'd', 'i', 'n', 'g', 's']
# []
# []
# ['v', 'e', 'r', 'g', 'a', 'n', 'g', 'e', 'n', 'e', 'n']
# []
# []
# ['i', 'f']
# []
# []
# ['a', 'f', 't', 'e', 'r']
# []
# []
# ['h', 'a', 'v', 'e', 'n']
# []
# []
# ['g', 'e', 'h', 'e', 'n']
# []
# []
# ['w', 'e', 'i', 't', 'e', 'r', 'e']
# []
# []
# ['d', 'a', 'r', 'f']
# []
# []
# ['b', 'e', 'f', 'o', 'r', 'e']
# []
# []
# ['i', 'n', 'd', 'e', 'm']
# []
# []
# ['j', 'u', 's', 't']
# []
# []
# ['n', 'o', 'c', 'h']
# []
# []
# ['b', 'e', 's', 's', 'e', 'r']
# []
# []
# ['z', 'w', 'e', 'i', 't', 'e', 'n']
# []
# []
# ['o', 'n']
# []
# []
# ['e', 'i', 'n', 'i', 'g', 'e', 'n']
# []
# []
# ['e', 'n', 't', 'w', 'e', 'd', 'e', 'r']
# []
# []
# ['o', 't', 'h', 'e', 'r']
# []
# []
# ['n', 'i', 'c', 'h', 't']
# []
# []
# ['d', 'e', 'i', 'n', 'e', 'r']
# []
# []
# ['e', 'l', 'f']
# []
# []
# ['l']
# []
# []
# ['d', 'o', 'e', 's']
# []
# []
# ['s', 'e', 'h', 'r']
# []
# []
# ['d', 'o', 'c', 'h']
# []
# []
# ['w', 'h', 'e', 'r', 'e']
# []
# []
# ['t', 'o', 'o']
# []
# []
# ['b', 'e', 'i']
# []
# []
# ['d', 'e', 'n', 's', 'e', 'l', 'b', 'e', 'n']
# []
# []
# ['a', 'u', 'f']
# []
# []
# ['d', 'e', 'r', 'e', 'r']
# []
# []
# ['m', 'ö', 'g', 'l', 'i', 'c', 'h']
# ['ö']
# ['o']
# ['d', 'e', 'i', 'n', 'e', 's']
# []
# []
# ['j', 'a', 'h', 'r']
# []
# []
# ['z', 'e', 'i', 't']
# []
# []
# ['e', 'u', 'e', 'r']
# []
# []
# ['e', 'i', 'n', 'e']
# []
# []
# ['u', 'n', 's', 'e', 'r', 'e', 'r']
# []
# []
# ['h', 'i', 'n']
# []
# []
# ['y', 'o', 'u', 'r']
# []
# []
# ['o', 'f', 'f', 'e', 'n']
# []
# []
# ['i', 's', 'n', 't']
# []
# []
# ['j', 'e', 'd', 'e', 'r', 'm', 'a', 'n', 'n']
# []
# []
# ['z', 'u', 'r', 'ü', 'c', 'k']
# ['ü']
# ['u']
# ['m', 'a', 'h', 'n']
# []
# []
# ['b', 'e', 'r', 'e', 'i', 't', 's']
# []
# []
# ['m', 'y']
# []
# []
# ['j', 'a', 'h', 'r', 'e']
# []
# []
# ['u', 'n', 'd']
# []
# []
# ['j', 'a']
# []
# []
# ['o', 'f', 'f']
# []
# []
# ['s', 'h', 'e', 's']
# []
# []
# ['s', 'u', 'c', 'h', 'e']
# []
# []
# ['b', 'e', 's', 'o', 'n', 'd', 'e', 'r', 's']
# []
# []
# ['r', 'e']
# []
# []
# ['m', 'a']
# []
# []
# ['g', 'e', 'w', 'o', 'r', 'd', 'e', 'n']
# []
# []
# ['a', 'u']
# []
# []
# ['d', 'e', 'n']
# []
# []
# ['g', 'e', 's', 'a', 'g', 't']
# []
# []
# ['z', 'e', 'h', 'n']
# []
# []
# ['m', 'a', 'c', 'h', 't']
# []
# []
# ['d', 'a', 'r', 'u', 'n', 't', 'e', 'r']
# []
# []
# ['a', 'u', 's', 's', 'e', 'r', 'd', 'e', 'm']
# []
# []
# ['d', 'u', 'r', 'f', 't', 'e']
# []
# []
# ['a', 'c', 'h', 't', 'e', 'r']
# []
# []
# ['w', 'e', 'i', 't']
# []
# []
# ['i', 'h', 'n']
# []
# []
# ['t', 'a', 'g', 'e', 'n']
# []
# []
# ['k', 'o', 'm', 'm', 't']
# []
# []
# ['i', 'n', 'f', 'o', 'l', 'g', 'e', 'd', 'e', 's', 's', 'e', 'n']
# []
# []
# ['b', 'e', 'i', 'd', 'e']
# []
# []
# ['b', 'u', 's', 'i', 'n', 'e', 's', 's', 'i', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e']
# ['ü']
# ['u']
# ['k', 'o', 'n', 'z', 'e', 'p', 't', 'i', 'o', 'n', 'c', 'u', 's', 't', 'o', 'm', 'i', 'z', 'i', 'n']
# []
# []
# ['a', 'l', 's', 'm', 'i', 't', 'g', 'l', 'i', 'e', 'd', 'e', 'i', 'n', 'e', 's', 'k', 'l', 'e', 'i']
# ['ü', 'ö', 'ö', 'ü', 'ö', 'ä', 'ö', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä']
# ['u', 'o', 'o', 'u', 'o', 'a', 'o', 'u', 'u', 'a', 'a', 'a', 'a', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ß', 'ö', 'ü', 'ü', 'ö', 'ä', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'ss', 'o', 'u', 'u', 'o', 'a', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ss'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ü', 'ö', 'ä', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ö', 'ä', 'ä', 'ä', 'ü', 'ü', 'ö', 'ö']
# ['u', 'u', 'u', 'o', 'a', 'u', 'u', 'a', 'u', 'u', 'a', 'a', 'o', 'a', 'a', 'a', 'u', 'u', 'o', 'o']
# ['d', 'i', 'g', 'i', 't', 'a', 'l', 'i', 's', 'i', 'e', 'r', 'u', 'n', 'g', 'i', 'n', 'd', 'e', 'r']
# ['ü', 'ä']
# ['u', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ß', 'ü', 'ä', 'ä', 'ü', 'ü', 'ü', 'ä', 'ä', 'ö', 'ä', 'ü', 'ä', 'ä', 'ä', 'ü', 'ö', 'ö']
# ['u', 'ss', 'u', 'a', 'a', 'u', 'u', 'u', 'a', 'a', 'o', 'a', 'u', 'a', 'a', 'a', 'u', 'o', 'o']
# ['i', 'h', 'r', 'e', 'a', 'u', 'f', 'g', 'a', 'b', 'e', 'n', 'm', 'i', 't', 'a', 'r', 'b', 'e', 'i']
# ['ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['a', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'f', 'ü', 'r']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['f', 'o', 'r', 'o', 'u', 'r', 'c', 'l', 'i', 'e', 'n', 't', 'a', 'g', 'l', 'o', 'b', 'a', 'l', 'l']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ü', 'ä', 'ä', 'ü', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'u', 'a', 'a', 'u', 'a', 'a', 'o', 'o']
# ['b', 'e', 'r', 'a', 't', 'u', 'n', 'g', 'p', 'l', 'a', 'n', 'u', 'n', 'g', 'u', 'n', 'd', 'r', 'e']
# ['ö', 'ö', 'ö', 'ä']
# ['o', 'o', 'o', 'a']
# ['t', 'e', 'c', 'h', 'n', 'i', 's', 'c', 'h', 'e', 'b', 'e', 'r', 'a', 't', 'u', 'n', 'g', 'm', 'i']
# ['ß', 'ö', 'ü', 'ö', 'ü']
# ['ss', 'o', 'u', 'o', 'u']
# ['a', 'k', 't', 'i', 'v', 'e', 'm', 'i', 't', 'a', 'r', 'b', 'e', 'i', 't', 'i', 'n', 'd', 'e', 'r']
# ['ä', 'ü', 'ü']
# ['a', 'u', 'u']
# ['k', 'o', 'n', 'z', 'e', 'p', 't', 'i', 'o', 'n', 'u', 'n', 'd', 'r', 'e', 'a', 'l', 'i', 's', 'i']
# ['ö']
# ['o']
# ['w', 'e', 'i', 't', 'e', 'r', 'e', 'n', 't', 'w', 'i', 'c', 'k', 'l', 'u', 'n', 'g', 'p', 'f', 'l']
# ['ü', 'ä']
# ['u', 'a']
# ['k', 'o', 'n', 'z', 'e', 'p', 't', 'i', 'o', 'n', 'p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'e']
# ['ö', 'ü', 'ä', 'ü', 'ü']
# ['o', 'u', 'a', 'u', 'u']
# ['t', 'e', 'c', 'h', 'n', 'i', 's', 'c', 'h', 'e', 's', 'a', 'p', 'b', 'e', 'r', 'a', 't', 'u', 'n']
# ['ä']
# ['a']
# ['d', 'e', 's', 'i', 'g', 'n', 'k', 'o', 'n', 'z', 'e', 'p', 't', 'i', 'o', 'n', 'u', 'n', 'd', 'u']
# ['ö', 'ü', 'ü']
# ['o', 'u', 'u']
# ['f', 'ü', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'e', 'i', 'n', 'u']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ü', 'ö', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä']
# ['u', 'u', 'u', 'u', 'u', 'a', 'a', 'u', 'u', 'o', 'a', 'a', 'a', 'a', 'a', 'a']
# ['i', 'h', 'r', 'e', 'a', 'u', 'f', 'g', 'a', 'b', 'e', 'n', 'm', 'i', 't', 'a', 'r', 'b', 'e', 'i']
# ['ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['a', 'a', 'a', 'a', 'o', 'o']
# ['f', 'ü', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'e', 'i', 'n', 'u']
# ['ü', 'ü', 'ä', 'ü', 'ä', 'ü', 'ü', 'ü', 'ä', 'ß', 'ü', 'ä', 'ö', 'ä', 'ü', 'ä', 'ü', 'ü', 'ä']
# ['u', 'u', 'a', 'u', 'a', 'u', 'u', 'u', 'a', 'ss', 'u', 'a', 'o', 'a', 'u', 'a', 'u', 'u', 'a']
# ['u', 'n', 't', 'e', 'r', 's', 't', 'ü', 't', 'z', 'u', 'n', 'g', 'd', 'e', 's', 'p', 'r', 'o', 'j']
# ['ü']
# ['u']
# ['t', 'e', 'c', 'h', 'n', 'i', 's', 'c', 'h', 'e', 's', 'u', 'p', 'p', 'o', 'r', 't', 't', 'ä', 't']
# ['ä', 'ä', 'ß', 'ä']
# ['a', 'a', 'ss', 'a']
# ['k', 'o', 'n', 'z', 'e', 'p', 't', 'i', 'o', 'n', 'e', 'n', 't', 'w', 'i', 'c', 'k', 'l', 'u', 'n']
# ['ü']
# ['u']
# ['s', 'c', 'r', 'e', 'e', 'n', 'd', 'e', 's', 'i', 'g', 'n']
# []
# []
# ['a', 'u', 'f', 'g', 'a', 'b', 'e', 'n', 'd', 'e', 'r', 'b', 'a', 't', 'c', 'h', 's', 't', 'e', 'u']
# ['ß', 'ü', 'ö', 'ü', 'ä', 'ä', 'ü', 'ä', 'ß', 'ü', 'ü', 'ä', 'ß', 'ß', 'ü', 'ü', 'ä', 'ü', 'ü', 'ü']
# ['ss', 'u', 'o', 'u', 'a', 'a', 'u', 'a', 'ss', 'u', 'u', 'a', 'ss', 'ss', 'u', 'u', 'a', 'u', 'u', 'u']
# ['b', 'e', 't', 'r', 'i', 'e', 'b', 's', 'b', 'e', 'r', 'e', 'i', 't', 's', 'c', 'h', 'a', 'f', 't']
# ['ä', 'ö', 'ü', 'ä']
# ['a', 'o', 'u', 'a']
# ['f', 'u', 't', 'u', 'r', 'e', 'c', 'o', 'n', 's', 'u', 'l', 't', 'i', 'n', 'g', 'g', 'm', 'b', 'h']
# ['ü', 'ü', 'ü', 'ä', 'ö', 'ä', 'ö', 'ß', 'ä', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ß']
# ['u', 'u', 'u', 'a', 'o', 'a', 'o', 'ss', 'a', 'u', 'u', 'u', 'u', 'u', 'u', 'a', 'u', 'u', 'a', 'ss']
# ['s', 'c', 'h', 'r', 'e', 'i', 'b', 't', 'r', 'o', 'b', 'u', 's', 't', 'e', 'n', 'u', 'n', 'd', 's']
# ['ö', 'ü']
# ['o', 'u']
# ['d', 'a', 's', 'w', 'e', 'i', 't', 'e', 'r', 'z', 'u', 'e', 'n', 't', 'w', 'i', 'c', 'k', 'e', 'l']
# ['ä', 'ü', 'ü', 'ä', 'ä', 'ö', 'ü', 'ü', 'ä', 'ü', 'ä']
# ['a', 'u', 'u', 'a', 'a', 'o', 'u', 'u', 'a', 'u', 'a']
# ['s', 'y', 's', 't', 'e', 'm', 'a', 'n', 'a', 'l', 'y', 's', 'e', 't', 'ä', 't', 'i', 'g', 'k', 'e']
# ['ä', 'ü', 'ä', 'ä']
# ['a', 'u', 'a', 'a']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'l', 'i', 'e', 'n', 't', 'o', 'u', 'r', 'c', 'l', 'i']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä', 'ö', 'ü', 'ö', 'ä', 'ü', 'ö', 'ö', 'ö']
# ['u', 'o', 'u', 'o', 'u', 'a', 'a', 'a', 'a', 'a', 'a', 'o', 'u', 'o', 'a', 'u', 'o', 'o', 'o']
# ['e', 'n', 't', 'w', 'i', 'c', 'k', 'l', 'u', 'n', 'g', 'n', 'a', 'c', 'h', 'c', 's', 's', 'j', 's']
# ['ö', 'ß']
# ['o', 'ss']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ä', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö']
# ['u', 'u', 'a', 'a', 'u', 'u', 'a', 'a', 'a', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'l', 'i', 'e', 'n', 't', 'o', 'u', 'r', 'c', 'l', 'i']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'a', 'a', 'a', 'o', 'o']
# ['s', 'i', 'c', 'h', 'e', 'r', 's', 't', 'e', 'l', 'l', 'u', 'n', 'g', 'd', 'e', 's', 'i', 't', 'b']
# ['ü', 'ä', 'ö', 'ä']
# ['u', 'a', 'o', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ß', 'ö', 'ä', 'ö', 'ß', 'ä', 'ä', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ö', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'ss', 'o', 'a', 'o', 'ss', 'a', 'a', 'a', 'u', 'u', 'a', 'u', 'a', 'o', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ö', 'ä', 'ä', 'ö']
# ['u', 'u', 'o', 'a', 'a', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ß', 'ö', 'ä', 'ö', 'ß', 'ä', 'ä', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ö', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'ss', 'o', 'a', 'o', 'ss', 'a', 'a', 'a', 'u', 'u', 'a', 'u', 'a', 'o', 'a', 'a', 'o', 'o']
# ['m', 'i', 't', 'a', 'r', 'b', 'e', 'i', 't', 'b', 'e', 'i', 'd', 'e', 'r', 'a', 'n', 'a', 'l', 'y']
# ['ö', 'ü', 'ü']
# ['o', 'u', 'u']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ß', 'ü', 'ä', 'ä', 'ä', 'ö']
# ['u', 'u', 'ss', 'u', 'a', 'a', 'a', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ö', 'ä', 'ü', 'ä', 'ü', 'ä', 'ö', 'ä', 'ä', 'ä', 'ö']
# ['u', 'o', 'o', 'a', 'u', 'a', 'u', 'a', 'o', 'a', 'a', 'a', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'a', 'u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ß', 'ä', 'ä', 'ü', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'ss', 'a', 'a', 'u', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ö', 'ö', 'ä']
# ['u', 'u', 'a', 'u', 'u', 'a', 'u', 'u', 'a', 'a', 'o', 'o', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ß', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'ss', 'u', 'a', 'u', 'u', 'a', 'u', 'a', 'u', 'a', 'a', 'a', 'o', 'o']
# ['s', 'i', 'c', 'h', 'e', 'r', 's', 't', 'e', 'l', 'l', 'u', 'n', 'g', 'v', 'o', 'n', 'm', 'a', 'n']
# ['ä', 'ö', 'ß', 'ü', 'ä', 'ä']
# ['a', 'o', 'ss', 'u', 'a', 'a']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ö', 'ü', 'ü', 'ö', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'a', 'o', 'u', 'u', 'o', 'a', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'a', 'a', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ö', 'ö']
# ['u', 'a', 'o', 'o']
# ['f', 'ü', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'n', 'ä', 'h', 'e']
# ['ü', 'ä', 'â', 'ü', 'â', 'â', 'â', 'ö', 'ä', 'ü', 'ä', 'ä', 'ä', 'â', 'ä', 'ä', 'â', 'ü', 'ü', 'â']
# ['u', 'a', 'â', 'u', 'â', 'â', 'â', 'o', 'a', 'u', 'a', 'a', 'a', 'â', 'a', 'a', 'â', 'u', 'u', 'â']
# ['i', 'c', 'h', 's', 'u', 'c', 'h', 'e', 'f', 'r', 'e', 'e', 'l', 'a', 'n', 'c', 'e', 'r', 'd', 'i']
# ['ö', 'ü', 'ä', 'ü', 'ä', 'ä', 'ä']
# ['o', 'u', 'a', 'u', 'a', 'a', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ö', 'ä', 'ü', 'ü', 'ä', 'ö', 'ü', 'ö', 'ä', 'ü', 'ä', 'ß', 'ä', 'ä', 'ä', 'ö', 'ö', 'ä']
# ['u', 'a', 'o', 'a', 'u', 'u', 'a', 'o', 'u', 'o', 'a', 'u', 'a', 'ss', 'a', 'a', 'a', 'o', 'o', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ß', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'a', 'ss', 'u', 'u', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ö', 'ä', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'o', 'a', 'u', 'a', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm', 'e', 'r', 'o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm']
# []
# []
# ['o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm', 'e', 'r', 'o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ö', 'ä', 'ü', 'ü', 'ä', 'ö', 'ü', 'ö', 'ä', 'ü', 'ä', 'ß', 'ä', 'ä', 'ä', 'ö', 'ö', 'ä']
# ['u', 'a', 'o', 'a', 'u', 'u', 'a', 'o', 'u', 'o', 'a', 'u', 'a', 'ss', 'a', 'a', 'a', 'o', 'o', 'a']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'u', 's', 't', 'o', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'f', 'ü', 'r']
# ['ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['y', 'o', 'u', 'r', 't', 'a', 's', 'k', 's', 'y', 'o', 'u', 'p', 'l', 'a', 'n', 'a', 'n', 'd', 'd']
# []
# []
# ['i', 'h', 'r', 'e', 'a', 'u', 'f', 'g', 'a', 'b', 'e', 'n', 'v', 'e', 'r', 'a', 'n', 't', 'w', 'o']
# ['ü', 'ü', 'ä', 'ä', 'ß', 'ü', 'ä', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä', 'ü', 'ä', 'ü']
# ['u', 'u', 'a', 'a', 'ss', 'u', 'a', 'u', 'a', 'a', 'a', 'a', 'a', 'u', 'a', 'u']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ß', 'ö', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'ss', 'o', 'u', 'u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'u', 's', 't', 'o', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ä', 'ü', 'ö', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'a', 'u', 'o', 'u', 'o', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'z', 'u', 'r']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ö', 'ß', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'u', 'u', 'a', 'o', 'ss', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ö', 'ü', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'o', 'u', 'u', 'o', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'o', 'u', 'a', 'a', 'a', 'o', 'o']
# ['e', 'r', 'f', 'o', 'l', 'g', 'i', 's', 't', 'm', 'a', 'ß', 'g', 'e', 'b', 'l', 'i', 'c', 'h', 'v']
# ['ß', 'ä', 'ä', 'ü', 'ä', 'ä', 'ö', 'ü', 'ü', 'ß', 'ß', 'ü', 'ä', 'ü', 'ß', 'ö', 'ö']
# ['ss', 'a', 'a', 'u', 'a', 'a', 'o', 'u', 'u', 'ss', 'ss', 'u', 'a', 'u', 'ss', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ü', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ö', 'ä', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'o', 'a', 'u', 'a', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['e', 'n', 't', 'w', 'i', 'c', 'k', 'l', 'u', 'n', 'g', 'v', 'o', 'n', 's', 'o', 'f', 't', 'w', 'a']
# ['ü', 'ö', 'ä', 'ä', 'ü', 'ö']
# ['u', 'o', 'a', 'a', 'u', 'o']
# ['r', 'e', 'a', 'l', 'i', 's', 'i', 'e', 'r', 'u', 'n', 'g', 'v', 'o', 'n', 'c', 'r', 'm', 'u', 'n']
# ['ö', 'ä', 'ä', 'ü', 'ö']
# ['o', 'a', 'a', 'u', 'o']
# ['s', 't', 'u', 't', 't', 'g', 'a', 'r', 't', 'o', 'n', 's', 'i', 't', 'e', 'o', 'd', 'e', 'r', 'd']
# ['ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ü', 'ü', 'ö', 'ü', 'ü', 'ä', 'ä', 'ü', 'ä', 'ü', 'ä']
# ['u', 'u', 'u', 'a', 'u', 'u', 'a', 'u', 'a', 'u', 'u', 'o', 'u', 'u', 'a', 'a', 'u', 'a', 'u', 'a']
# ['s', 't', 'u', 't', 't', 'g', 'a', 'r', 't', 'o', 'n', 's', 'i', 't', 'e', 'o', 'd', 'e', 'r', 'd']
# ['ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ü', 'ü', 'ö', 'ü', 'ü', 'ä', 'ä', 'ü', 'ä', 'ü', 'ä']
# ['u', 'u', 'u', 'a', 'u', 'u', 'a', 'u', 'a', 'u', 'u', 'o', 'u', 'u', 'a', 'a', 'u', 'a', 'u', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ß', 'ü', 'ä', 'ä', 'ö']
# ['u', 'a', 'ss', 'u', 'a', 'a', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ß', 'ü', 'ä', 'ä', 'ö']
# ['u', 'a', 'ss', 'u', 'a', 'a', 'o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ß', 'ü', 'ü', 'ä', 'ä', 'ö']
# ['u', 'a', 'ss', 'u', 'u', 'a', 'a', 'o']
# ['e', 'r', 'f', 'a', 'h', 'r', 'u', 'n', 'g', 'e', 'n', 'm', 'i', 't', 's', 'a', 'p', 'p', 'o', 'k']
# ['ä', 'ü', 'ö', 'ü', 'ü', 'ü', 'ö', 'ß']
# ['a', 'u', 'o', 'u', 'u', 'u', 'o', 'ss']
# ['a', 'n', 'f', 'o', 'r', 'd', 'e', 'r', 'u', 'n', 'g', 'e', 'n', 'r', 'e', 'd', 'h', 'a', 't', 'e']
# ['ü']
# ['u']
# ['g', 'e', 's', 'u', 'c', 'h', 't', 'w', 'i', 'r', 'd', 'e', 'i', 'n', 'a', 'r', 'c', 'h', 'i', 't']
# ['ü', 'ä', 'ä', 'ü', 'ü', 'ü', 'ä']
# ['u', 'a', 'a', 'u', 'u', 'u', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ü', 'ö', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'u', 'o', 'a', 'a', 'a', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'o', 's', 't', 'u', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['s', 'u', 'p', 'p', 'o', 'r', 't', 'e', 'r', 'f', 'a', 'h', 'r', 'u', 'n', 'g', 's', 't', 'l', 'e']
# ['ö', 'ß']
# ['o', 'ss']
# ['f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'u', 'n', 's', 'e', 'r', 'e', 'r', 'g', 'r', 'o', 'ß', 'k']
# ['ü', 'ß', 'ü', 'ü', 'ä', 'ß', 'ü', 'ü', 'ä', 'ü', 'ö', 'ä', 'ä', 'ü']
# ['u', 'ss', 'u', 'u', 'a', 'ss', 'u', 'u', 'a', 'u', 'o', 'a', 'a', 'u']
# ['w', 'i', 'r', 's', 'u', 'c', 'h', 'e', 'n', 'f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'k', 'u', 'n']
# ['ü']
# ['u']
# ['f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'u', 'n', 's', 'e', 'r', 'e', 'r', 'g', 'r', 'o', 'ß', 'k']
# ['ü', 'ß', 'ü', 'ä', 'ö', 'ü', 'ü', 'ß', 'ß', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü']
# ['u', 'ss', 'u', 'a', 'o', 'u', 'u', 'ss', 'ss', 'u', 'u', 'u', 'u', 'u', 'u', 'u']
# ['j', 'a', 'v', 'a', 's', 'c', 'r', 'i', 'p', 't', 'f', 'r', 'a', 'm', 'e', 'w', 'o', 'r', 'k', 's']
# ['ö']
# ['o']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ü', 'ä', 'ü', 'ü', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'o', 'u', 'a', 'u', 'u', 'a', 'a', 'a', 'o', 'o']
# ['c', 'i', 's', 'c', 'o', 'n', 'a', 'c', 'h', 's', 'ü', 'g', 'l', 's', 'a', 'ü', 'b', 'e', 'r', 'p']
# ['ü', 'ü', 'ü', 'ö', 'ö', 'ü', 'ü', 'ü', 'ö', 'ü', 'ö', 'ü', 'ö', 'ü']
# ['u', 'u', 'u', 'o', 'o', 'u', 'u', 'u', 'o', 'u', 'o', 'u', 'o', 'u']
# ['j', 'a', 'v', 'a', 's', 'y', 's', 't', 'e', 'm', 'd', 'e', 'v', 'e', 'l', 'o', 'p', 'm', 'e', 'n']
# ['ä', 'ü']
# ['a', 'u']
# ['a', 'd', 'o', 'b', 'e', 'e', 'x', 'p', 'e', 'r', 'i', 'e', 'n', 'c', 'e', 'm', 'a', 'n', 'a', 'g']
# ['ä', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ü', 'ö', 'ö']
# ['a', 'u', 'u', 'u', 'u', 'a', 'a', 'a', 'u', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'l', 'i', 'e', 'n', 't', 'o', 'u', 'r', 'c', 'l', 'i']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ü', 'ö', 'ü', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö', 'ö']
# ['u', 'u', 'o', 'u', 'u', 'o', 'u', 'a', 'a', 'a', 'a', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'l', 'i', 'e', 'n', 't', 'o', 'u', 'r', 'c', 'l', 'i']
# []
# []
# ['s', 'o', 'f', 't', 'w', 'a', 'r', 'e', 't', 'o', 'o', 'l', 'k', 'e', 't', 't', 'e', 'c', 'o', 'm']
# ['ü', 'ä', 'ß', 'ü', 'ü', 'ä', 'ß', 'ü', 'ä', 'ä', 'ü', 'ß']
# ['u', 'a', 'ss', 'u', 'u', 'a', 'ss', 'u', 'a', 'a', 'u', 'ss']
# ['e', 'r', 'f', 'a', 'h', 'r', 'u', 'n', 'g', 'm', 'i', 't', 'r', 'e', 'g', 'i', 'o', 'n', 'a', 'l']
# ['ä', 'ü', 'ä', 'ü', 'ä', 'ä', 'ö', 'ü', 'ü', 'ö', 'ö', 'ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ü', 'ä', 'ö']
# ['a', 'u', 'a', 'u', 'a', 'a', 'o', 'u', 'u', 'o', 'o', 'u', 'u', 'u', 'u', 'u', 'a', 'u', 'a', 'o']
# ['j', 'a', 'v', 'a', 's', 'p', 'r', 'i', 'n', 'g', 'c', 'o', 'r', 'e', 'h', 'i', 'b', 'e', 'r', 'n']
# ['ü', 'ä', 'ö', 'ä', 'ü', 'ö', 'ü', 'ö', 'ö', 'ö', 'ä', 'ü', 'ä', 'ö', 'ü', 'ü', 'ä', 'ü']
# ['u', 'a', 'o', 'a', 'u', 'o', 'u', 'o', 'o', 'o', 'a', 'u', 'a', 'o', 'u', 'u', 'a', 'u']
# ['j', 'a', 'v', 'a', 'j', 'a', 'v', 'a', 'e', 'e', 'e', 'e', 'a', 'p', 'a', 'c', 'h', 'e', 't', 'o']
# ['ß', 'ö', 'ü', 'ß']
# ['ss', 'o', 'u', 'ss']
# ['s', 'e', 'h', 'r', 'g', 'e', 'e', 'h', 'r', 't', 'e', 'd', 'a', 'm', 'e', 'n', 'u', 'n', 'd', 'h']
# ['ü', 'ä', 'ö', 'ä', 'ü', 'ä', 'ü', 'ä', 'ä', 'ä', 'ü', 'ä', 'ä', 'ä', 'ä', 'ü', 'ä', 'ü', 'ü', 'ü']
# ['u', 'a', 'o', 'a', 'u', 'a', 'u', 'a', 'a', 'a', 'u', 'a', 'a', 'a', 'a', 'u', 'a', 'u', 'u', 'u']
# ['f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'u', 'n', 's', 'e', 'r', 'e', 'r', 'g', 'r', 'o', 'ß', 'k']
# ['ü', 'ß', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä']
# ['u', 'ss', 'u', 'u', 'u', 'u', 'a', 'a', 'a', 'a']
# ['s', 'e', 'n', 'i', 'o', 'r', 'e', 'n', 't', 'w', 'i', 'c', 'k', 'l', 'e', 'r', 'c', 'l', 'i', 'e']
# ['ä', 'ü', 'ö', 'ä', 'ß', 'ö']
# ['a', 'u', 'o', 'a', 'ss', 'o']
# ['f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'u', 'n', 's', 'e', 'r', 'e', 'r', 'g', 'r', 'o', 'ß', 'k']
# ['ü', 'ß', 'ü', 'ü', 'ß', 'ü', 'ä', 'ä', 'ä', 'ü', 'ä', 'ä', 'ü', 'ä', 'ä', 'ä', 'ä', 'ü', 'ü', 'ä']
# ['u', 'ss', 'u', 'u', 'ss', 'u', 'a', 'a', 'a', 'u', 'a', 'a', 'u', 'a', 'a', 'a', 'a', 'u', 'u', 'a']
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ä', 'ä', 'ä', 'ü', 'ä', 'ä', 'ä', 'ü', 'ä', 'ö', 'ö']
# ['u', 'a', 'a', 'a', 'u', 'a', 'a', 'a', 'u', 'a', 'o', 'o']
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'u', 's', 't', 'o', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['a', 'b', 'o', 'u', 't', 'o', 'u', 'r', 'c', 'u', 's', 't', 'o', 'm', 'e', 'r', 'o', 'u', 'r', 'c']
# []
# []
# ['ü', 'b', 'e', 'r', 'u', 'n', 's', 'e', 'r', 'e', 'n', 'k', 'u', 'n', 'd', 'e', 'n', 'u', 'n', 's']
# ['ü', 'ö', 'ü', 'ü', 'ö', 'ä', 'ö', 'ö', 'ö']
# ['u', 'o', 'u', 'u', 'o', 'a', 'o', 'o', 'o']
# ['f', 'ü', 'r', 'e', 'i', 'n', 'e', 'n', 'u', 'n', 's', 'e', 'r', 'e', 'r', 'g', 'r', 'o', 'ß', 'k']
# ...
# ['ß', 'ö']
# ['ss', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ö', 'ä', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ß']
# ['u', 'u', 'o', 'a', 'u', 'u', 'u', 'u', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ü', 'ü', 'ä', 'ö']
# ['u', 'a', 'u', 'u', 'u', 'a', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü']
# ['u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ü', 'ü', 'ö', 'ü', 'ä', 'ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ß']
# ['a', 'u', 'u', 'o', 'u', 'a', 'u', 'u', 'u', 'a', 'a', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ä', 'ü', 'ä', 'ß', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ö', 'ü', 'ß', 'ö', 'ü', 'ö', 'ü']
# ['u', 'u', 'u', 'a', 'u', 'a', 'ss', 'u', 'u', 'u', 'u', 'u', 'u', 'o', 'u', 'ss', 'o', 'u', 'o', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ö', 'ü', 'ü', 'ü', 'ü', 'ä', 'ü', 'ö', 'ö', 'ä', 'ö', 'ü', 'ü']
# ['u', 'u', 'u', 'o', 'u', 'u', 'u', 'u', 'a', 'u', 'o', 'o', 'a', 'o', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ö', 'ß', 'ü', 'ü', 'ü', 'ä', 'ü', 'ä', 'ä', 'ü', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'u', 'a', 'a', 'u', 'o', 'ss', 'u', 'u', 'u', 'a', 'u', 'a', 'a', 'u', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ü', 'ä', 'ß', 'ö', 'ü', 'ü', 'ü']
# ['a', 'u', 'a', 'ss', 'o', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ü', 'ä']
# ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'a', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# []
# []
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ö', 'ü', 'ö', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ü']
# ['u', 'o', 'o', 'u', 'o', 'u', 'u', 'a', 'a', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ä', 'ü', 'ö', 'ä', 'ö', 'ü', 'ö', 'ä', 'ö', 'ä', 'ö', 'ö']
# ['u', 'o', 'a', 'u', 'o', 'a', 'o', 'u', 'o', 'a', 'o', 'a', 'o', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ü', 'ü', 'ä', 'ö', 'ä', 'ß', 'ä', 'ü', 'ä', 'ü', 'ü', 'ü', 'ß']
# ['u', 'a', 'u', 'u', 'u', 'a', 'o', 'a', 'ss', 'a', 'u', 'a', 'u', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü']
# ['u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ö', 'ß', 'ü', 'ä', 'ö', 'ä', 'ü', 'ö', 'ü', 'ä', 'ü', 'ä', 'ä', 'ä', 'ü', 'ü']
# ['u', 'u', 'u', 'u', 'o', 'ss', 'u', 'a', 'o', 'a', 'u', 'o', 'u', 'a', 'u', 'a', 'a', 'a', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ü', 'ö', 'ä', 'ö', 'ä']
# ['a', 'u', 'o', 'a', 'o', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ö', 'ü', 'ü', 'ü', 'ü', 'ö', 'ä', 'ä', 'ß', 'ö', 'ö', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ö']
# ['u', 'u', 'o', 'u', 'u', 'u', 'u', 'o', 'a', 'a', 'ss', 'o', 'o', 'u', 'u', 'a', 'a', 'a', 'a', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ä', 'ü', 'ä', 'ä', 'ß', 'ü', 'ä', 'ä', 'ä', 'ß', 'ä', 'ö', 'ä', 'ä', 'ü', 'ü', 'ö', 'ü', 'ö']
# ['a', 'a', 'u', 'a', 'a', 'ss', 'u', 'a', 'a', 'a', 'ss', 'a', 'o', 'a', 'a', 'u', 'u', 'o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ä', 'ü', 'ä', 'ä', 'ß', 'ü', 'ä', 'ä', 'ä', 'ß', 'ä', 'ö', 'ä', 'ä', 'ü', 'ü', 'ö', 'ü', 'ö']
# ['a', 'a', 'u', 'a', 'a', 'ss', 'u', 'a', 'a', 'a', 'ss', 'a', 'o', 'a', 'a', 'u', 'u', 'o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ö', 'ü', 'ü', 'ä', 'ö', 'ä', 'ä', 'ä', 'ä', 'ä', 'ß', 'ü', 'ä', 'ö', 'ö', 'ä', 'ß', 'ü', 'ä']
# ['o', 'u', 'u', 'a', 'o', 'a', 'a', 'a', 'a', 'a', 'ss', 'u', 'a', 'o', 'o', 'a', 'ss', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ö', 'ü', 'ö']
# ['u', 'u', 'u', 'u', 'a', 'o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ö', 'ü']
# ['u', 'a', 'o', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ß', 'ä', 'ü', 'ü', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'u', 'ss', 'a', 'u', 'u', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ö', 'ä', 'ö', 'ü', 'ä']
# ['u', 'u', 'u', 'u', 'u', 'u', 'a', 'a', 'o', 'a', 'o', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ä', 'ö']
# ['a', 'a', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ü', 'ü', 'ü', 'ü', 'ü', 'ö', 'ß', 'ö', 'ü', 'ü', 'ü', 'ß']
# ['u', 'u', 'a', 'u', 'u', 'u', 'u', 'u', 'o', 'ss', 'o', 'u', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ä', 'ü', 'ü', 'ß', 'ü', 'ü', 'ü', 'ü']
# ['u', 'u', 'a', 'a', 'u', 'u', 'ss', 'u', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ü', 'ü', 'ü', 'ü', 'ß']
# ['u', 'o', 'u', 'a', 'u', 'u', 'a', 'u', 'a', 'u', 'u', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ü', 'ü', 'ö', 'ü', 'ä', 'ö', 'ü']
# ['u', 'u', 'a', 'u', 'u', 'o', 'u', 'a', 'o', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ä', 'ä', 'ä', 'ü']
# ['u', 'a', 'a', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ä', 'ü', 'ß', 'ö', 'ä', 'ü']
# ['u', 'u', 'u', 'a', 'a', 'u', 'a', 'u', 'ss', 'o', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# []
# []
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ä', 'ö', 'ä', 'ä', 'ü']
# ['u', 'a', 'u', 'a', 'o', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ö', 'ü', 'ü', 'ü', 'ü', 'ü', 'ö', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä', 'ü']
# ['u', 'u', 'u', 'u', 'u', 'o', 'u', 'u', 'u', 'u', 'u', 'o', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ß', 'ä', 'ß', 'ü', 'ü', 'ä', 'ü', 'ö', 'ü', 'ö', 'ä', 'ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü']
# ['a', 'ss', 'a', 'ss', 'u', 'u', 'a', 'u', 'o', 'u', 'o', 'a', 'u', 'u', 'u', 'a', 'u', 'u', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ö']
# ['u', 'a', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ö', 'ü', 'ß', 'ü']
# ['u', 'a', 'u', 'o', 'u', 'ss', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ä', 'ä', 'ü', 'ß', 'ä', 'ö', 'ö', 'ä', 'ü']
# ['u', 'u', 'a', 'a', 'a', 'u', 'ss', 'a', 'o', 'o', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ü', 'ä', 'ö', 'ä', 'ä', 'ü']
# ['u', 'a', 'u', 'u', 'a', 'o', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ß', 'ü', 'ä', 'ü', 'ä', 'ü', 'ö', 'ä', 'ß']
# ['u', 'u', 'u', 'u', 'a', 'a', 'ss', 'u', 'a', 'u', 'a', 'u', 'o', 'a', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ß', 'ö', 'ä', 'ü']
# ['u', 'u', 'u', 'u', 'ss', 'o', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ö', 'ü', 'ö', 'ü', 'ä', 'ö', 'ä', 'ä', 'ä', 'ü', 'ö']
# ['u', 'a', 'o', 'u', 'o', 'u', 'a', 'o', 'a', 'a', 'a', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ä', 'ü', 'ß', 'ö', 'ä', 'ü']
# ['u', 'o', 'a', 'u', 'ss', 'o', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ü', 'ö', 'ü', 'ü', 'ö', 'ü', 'ä', 'ä', 'ä', 'ß', 'ö', 'ü', 'ä']
# ['u', 'o', 'u', 'o', 'u', 'u', 'o', 'u', 'a', 'a', 'a', 'ss', 'o', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['â', 'â', 'ü']
# ['â', 'â', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü']
# ['u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ä']
# ['u', 'u', 'a', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ä', 'ö', 'ü', 'ä', 'ö', 'ü', 'ü', 'ß']
# ['u', 'a', 'u', 'a', 'o', 'u', 'a', 'o', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ä', 'ä', 'ü']
# ['u', 'u', 'u', 'u', 'a', 'a', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ß', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä', 'ü']
# ['u', 'u', 'u', 'a', 'a', 'u', 'ss', 'a', 'a', 'a', 'a', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü']
# ['u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ü', 'ä', 'ä', 'ö', 'ä']
# ['a', 'u', 'a', 'a', 'o', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä', 'ä', 'ü', 'ä', 'ä', 'ö']
# ['a', 'u', 'a', 'a', 'a', 'a', 'a', 'a', 'u', 'a', 'a', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ö', 'ö', 'ü', 'ö', 'ü', 'ü', 'ß', 'ü', 'ä', 'ü']
# ['o', 'o', 'u', 'o', 'u', 'u', 'ss', 'u', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ä', 'ü', 'ü', 'ü', 'ü', 'ß', 'ü', 'ö', 'ü', 'ö', 'ä', 'ü', 'ü', 'ü', 'ä', 'ü', 'ü']
# ['u', 'a', 'u', 'a', 'u', 'u', 'u', 'u', 'ss', 'u', 'o', 'u', 'o', 'a', 'u', 'u', 'u', 'a', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ü', 'ß', 'ö']
# ['u', 'u', 'u', 'u', 'a', 'u', 'u', 'u', 'ss', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ö', 'ü', 'ü', 'ü', 'ü', 'ä', 'ä', 'ü', 'ß', 'ä', 'ä', 'ä', 'ü', 'ü', 'ü', 'ß', 'ö']
# ['u', 'a', 'o', 'u', 'u', 'u', 'u', 'a', 'a', 'u', 'ss', 'a', 'a', 'a', 'u', 'u', 'u', 'ss', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ä', 'ü', 'ä', 'ä', 'ä', 'ä', 'ü', 'ä']
# ['u', 'u', 'a', 'a', 'u', 'a', 'a', 'a', 'a', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ä', 'ö', 'ü', 'ö']
# ['u', 'u', 'u', 'u', 'a', 'o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# []
# []
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ä', 'ä', 'ä', 'ö', 'ä', 'ä', 'ü', 'ß', 'ü', 'ü', 'ü', 'ü', 'ö', 'ö', 'ü', 'ö']
# ['a', 'a', 'a', 'o', 'a', 'a', 'u', 'ss', 'u', 'u', 'u', 'u', 'o', 'o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# []
# []
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ä', 'ä', 'ü', 'ö', 'ü', 'ö', 'ä', 'ü', 'ü', 'ü', 'ä', 'ü', 'ü', 'ä', 'ü', 'ä', 'ä', 'ü']
# ['u', 'u', 'a', 'a', 'u', 'o', 'u', 'o', 'a', 'u', 'u', 'u', 'a', 'u', 'u', 'a', 'u', 'a', 'a', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ß', 'ü', 'ß', 'ü', 'ä', 'ö', 'ö', 'ö', 'ä', 'ü', 'ü', 'ü', 'ü', 'ö', 'ü', 'ü', 'ß']
# ['u', 'a', 'ss', 'u', 'ss', 'u', 'a', 'o', 'o', 'o', 'a', 'u', 'u', 'u', 'u', 'o', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ü', 'ü', 'ü', 'ü', 'ö', 'ä', 'ä', 'ß', 'ö', 'ö', 'ü', 'ä', 'ä', 'ä', 'ä', 'ä', 'ß', 'ü']
# ['u', 'o', 'u', 'u', 'u', 'u', 'o', 'a', 'a', 'ss', 'o', 'o', 'u', 'a', 'a', 'a', 'a', 'a', 'ss', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ü', 'ß', 'ä', 'ß', 'ü', 'ü', 'ä', 'ü', 'ä']
# ['u', 'u', 'u', 'u', 'u', 'u', 'ss', 'a', 'ss', 'u', 'u', 'a', 'u', 'a']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ä', 'ü', 'ü', 'ö', 'ü', 'ß', 'ß']
# ['u', 'a', 'u', 'u', 'o', 'u', 'ss', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ö', 'ß', 'ü', 'ä', 'ö', 'ä', 'ü', 'ö', 'ü', 'ä', 'ä', 'ü', 'ü', 'ä', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'o', 'ss', 'u', 'a', 'o', 'a', 'u', 'o', 'u', 'a', 'a', 'u', 'u', 'a', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ö', 'ü', 'ö']
# ['o', 'u', 'o']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ö', 'ö', 'ü', 'ü', 'ß', 'ö', 'ö', 'ä', 'ä', 'ü', 'ü', 'ü', 'ö', 'ü']
# ['u', 'o', 'o', 'u', 'u', 'ss', 'o', 'o', 'a', 'a', 'u', 'u', 'u', 'o', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ß']
# ['u', 'u', 'u', 'u', 'ss']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ö', 'ä', 'ö', 'ö', 'ö', 'ü', 'ü', 'ü']
# ['u', 'u', 'u', 'o', 'a', 'o', 'o', 'o', 'u', 'u', 'u']
# ['p', 'r', 'o', 'j', 'e', 'k', 't', 'b', 'e', 's', 'c', 'h', 'r', 'e', 'i', 'b', 'u', 'n', 'g', 'm']
# ['ü', 'ü', 'ü', 'ü', 'ü', 'ä']
# ['u', 'u', 'u', 'u', 'u', 'a']
# CPU times: user 2min 3s, sys: 1.4 s, total: 2min 5s
# Wall time: 2min 5s
# (5360, 1)

# %%
terms = tfidf_vectorizer.get_feature_names()
terms
# Out:
# ['ss']

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)
dist
# Out:
# array([[-2.22044605e-16,  1.00000000e+00,  8.64780483e-01, ...,
#          7.62872459e-01,  5.47389137e-01,  5.81232584e-01],
#        [ 1.00000000e+00,  0.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 8.64780483e-01,  1.00000000e+00,  0.00000000e+00, ...,
#          9.67935728e-01,  8.54688701e-01,  8.19076957e-01],
#        ...,
#        [ 7.62872459e-01,  1.00000000e+00,  9.67935728e-01, ...,
#          0.00000000e+00,  5.86348037e-01,  5.67144662e-01],
#        [ 5.47389137e-01,  1.00000000e+00,  8.54688701e-01, ...,
#          5.86348037e-01, -2.22044605e-16,  8.01994160e-01],
#        [ 5.81232584e-01,  1.00000000e+00,  8.19076957e-01, ...,
#          5.67144662e-01,  8.01994160e-01, -4.44089210e-16]])

# %%
from sklearn.cluster import KMeans

num_clusters = 3 

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 19.4 s, sys: 260 ms, total: 19.6 s
# Wall time: 19.8 s

# %%
from sklearn.externals import joblib

joblib.dump(km,  'doc_cluster.pkl')

km = joblib.load('doc_cluster.pkl')
clusters = km.labels_.tolist()

# %%
projects = {'description': description, 'cluster': clusters }

frame = pd.DataFrame(projects, index = [clusters] , columns = ['cluster', 'description'])

# %%
frame['cluster'].value_counts()
# Out:
# 0    3575
# 1    1100
# 2     685
# Name: cluster, dtype: int64

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace
    
    #print("Cluster %d titles:" % i, end='')
    #for title in frame.ix[i]['title'].values.tolist():
     #   print(' %s,' % title, end='')
    print() #add whitespace
    print() #add whitespace
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':
#  b'f\xc3\xbcr', b'erfahrung', b'kenntnisse', b'entwicklung', b'gute', b'kunde',
#
#
#
# Cluster 1 words: b'sap', b'beratung', b'f\xc3\xbcr', b'erfahrung', b'kunde', b'projektes',
#
#
#
# Cluster 2 words: b'skills', b'teams', b'java', b'start', b'asap', b'profil',
